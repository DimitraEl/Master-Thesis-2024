# %%
import pandas as pd

metadata = pd.read_csv("sample_info.csv")

drug_sensitivity = pd.read_excel('GDSC2_fitted_dose_response_25Feb20.xlsx', engine='openpyxl')
gene_expression = pd.read_csv('CCLE_expression.csv', index_col=0)


print("\nDrug Sensitivity Data:")
print(drug_sensitivity.head())
# Out:
# Drug Sensitivity Data:
#   DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0   GDSC2             282       13320532     749709        HCC1954
# 1   GDSC2             282       13320565     749710        HCC1143
# 2   GDSC2             282       13320598     749711        HCC1187
# 3   GDSC2             282       13320631     749712        HCC1395
# 4   GDSC2             282       13320668     749713        HCC1599
#
#   SANGER_MODEL_ID TCGA_DESC  DRUG_ID     DRUG_NAME PUTATIVE_TARGET  \
# 0       SIDM00872      BRCA     1003  Camptothecin            TOP1
# 1       SIDM00866      BRCA     1003  Camptothecin            TOP1
# 2       SIDM00885      BRCA     1003  Camptothecin            TOP1
# 3       SIDM00884      BRCA     1003  Camptothecin            TOP1
# 4       SIDM00877      BRCA     1003  Camptothecin            TOP1
#
#       PATHWAY_NAME  COMPANY_ID WEBRELEASE  MIN_CONC  MAX_CONC   LN_IC50  \
# ...

# %%
drug_sensitivity
# Out:
#        DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0        GDSC2             282       13320532     749709        HCC1954
# 1        GDSC2             282       13320565     749710        HCC1143
# 2        GDSC2             282       13320598     749711        HCC1187
# 3        GDSC2             282       13320631     749712        HCC1395
# 4        GDSC2             282       13320668     749713        HCC1599
# ...        ...             ...            ...        ...            ...
# 135237   GDSC2             282       13322622    1290798       EFM-192A
# 135238   GDSC2             282       13322655    1290905        HCC1428
# 135239   GDSC2             282       13322694    1290922         HDQ-P1
# 135240   GDSC2             282       13322727    1298157         JIMT-1
# 135241   GDSC2             282       13322759    1303900        HCC1500
#
#        SANGER_MODEL_ID TCGA_DESC  DRUG_ID     DRUG_NAME  \
# ...

# %%
# Filter the drug sensitivity data for Lapatinib
lapatinib_df = drug_sensitivity[drug_sensitivity['DRUG_NAME'].str.lower() == 'lapatinib']
lapatinib_df.head()
# Out:
#       DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 51103   GDSC2             282       13320559     749709        HCC1954
# 51104   GDSC2             282       13320592     749710        HCC1143
# 51105   GDSC2             282       13320625     749711        HCC1187
# 51106   GDSC2             282       13320662     749712        HCC1395
# 51107   GDSC2             282       13320703     749713        HCC1599
#
#       SANGER_MODEL_ID TCGA_DESC  DRUG_ID  DRUG_NAME PUTATIVE_TARGET  \
# 51103       SIDM00872      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51104       SIDM00866      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51105       SIDM00885      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51106       SIDM00884      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51107       SIDM00877      BRCA     1558  Lapatinib     EGFR, ERBB2
#
#          PATHWAY_NAME  COMPANY_ID WEBRELEASE  MIN_CONC  MAX_CONC   LN_IC50  \
# ...

# %%
import pandas as pd

print(drug_sensitivity.head())

print(drug_sensitivity.info())

print(drug_sensitivity.describe())
# Out:
#   DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0   GDSC2             282       13320532     749709        HCC1954
# 1   GDSC2             282       13320565     749710        HCC1143
# 2   GDSC2             282       13320598     749711        HCC1187
# 3   GDSC2             282       13320631     749712        HCC1395
# 4   GDSC2             282       13320668     749713        HCC1599
#
#   SANGER_MODEL_ID TCGA_DESC  DRUG_ID     DRUG_NAME PUTATIVE_TARGET  \
# 0       SIDM00872      BRCA     1003  Camptothecin            TOP1
# 1       SIDM00866      BRCA     1003  Camptothecin            TOP1
# 2       SIDM00885      BRCA     1003  Camptothecin            TOP1
# 3       SIDM00884      BRCA     1003  Camptothecin            TOP1
# 4       SIDM00877      BRCA     1003  Camptothecin            TOP1
#
#       PATHWAY_NAME  COMPANY_ID WEBRELEASE  MIN_CONC  MAX_CONC   LN_IC50  \
# 0  DNA replication        1046          Y  0.000098       0.1 -0.251083
# ...

# %%
lapatinib_data = drug_sensitivity[drug_sensitivity['DRUG_NAME'] == 'Lapatinib']

print(lapatinib_data.head())
print(f"Number of cell lines tested with Lapatinib: {len(lapatinib_data)}")
# Out:
#       DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 51103   GDSC2             282       13320559     749709        HCC1954
# 51104   GDSC2             282       13320592     749710        HCC1143
# 51105   GDSC2             282       13320625     749711        HCC1187
# 51106   GDSC2             282       13320662     749712        HCC1395
# 51107   GDSC2             282       13320703     749713        HCC1599
#
#       SANGER_MODEL_ID TCGA_DESC  DRUG_ID  DRUG_NAME PUTATIVE_TARGET  \
# 51103       SIDM00872      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51104       SIDM00866      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51105       SIDM00885      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51106       SIDM00884      BRCA     1558  Lapatinib     EGFR, ERBB2
# 51107       SIDM00877      BRCA     1558  Lapatinib     EGFR, ERBB2
#
#          PATHWAY_NAME  COMPANY_ID WEBRELEASE  MIN_CONC  MAX_CONC   LN_IC50  \
# ...

# %%
ln_ic50 = lapatinib_data['LN_IC50']

print(ln_ic50.describe())
# Out:
# count    757.000000
# mean       3.041682
# std        1.623400
# min       -2.045392
# 25%        1.911388
# 50%        2.783061
# 75%        4.168839
# max        8.060205
# Name: LN_IC50, dtype: float64

# %%
print(f"Missing LN_IC50 values: {ln_ic50.isna().sum()}")
lapatinib_data_cleaned = lapatinib_data.dropna(subset=['LN_IC50'])
# Out:
# Missing LN_IC50 values: 0

# %%
import matplotlib.pyplot as plt
import seaborn as sns

plt.figure(figsize=(8, 5))
sns.histplot(ln_ic50, kde=True, bins=30, color="blue")
plt.title("Distribution of Lapatinib Sensitivity (LN_IC50)")
plt.xlabel("LN_IC50")
plt.ylabel("Frequency")
plt.show()
plt.savefig("Distribution of Lapatinib Sensitivity")
# Out:
# C:\Users\dimim\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
plt.figure(figsize=(8, 5))
sns.boxplot(x=ln_ic50, color="skyblue")
plt.title("Boxplot of Lapatinib Sensitivity (LN_IC50)")
plt.xlabel("LN_IC50")
plt.savefig("boxplot of lap sensitivity")
plt.show()

# %%
merged_data = pd.merge(metadata, lapatinib_data, how='inner', left_on='Sanger_Model_ID', right_on='SANGER_MODEL_ID')

tissue_sensitivity = merged_data.groupby('lineage')['LN_IC50'].mean()

plt.figure(figsize=(12, 6))
tissue_sensitivity.sort_values().plot(kind="bar", color="coral")
plt.title("Average Lapatinib Sensitivity by Tissue Type")
plt.ylabel("Mean LN_IC50")
plt.xlabel("Tissue Type")
plt.xticks(rotation=45)
plt.savefig("Average Lap Sensitivity by Tissue Type")
plt.show()

# %%
# Identify highly sensitive cell lines
low_sensitivity = lapatinib_data[lapatinib_data['LN_IC50'] < ln_ic50.quantile(0.05)]
print("Highly sensitive cell lines:")
print(low_sensitivity[['SANGER_MODEL_ID', 'LN_IC50']])

# Identify highly resistant cell lines
high_resistance = lapatinib_data[lapatinib_data['LN_IC50'] > ln_ic50.quantile(0.95)]
print("Highly resistant cell lines:")
print(high_resistance[['SANGER_MODEL_ID', 'LN_IC50']])
# Out:
# Highly sensitive cell lines:
#       SANGER_MODEL_ID   LN_IC50
# 51110       SIDM00772 -0.711926
# 51126       SIDM00633 -1.944905
# 51128       SIDM00272  0.707376
# 51131       SIDM00241  0.709547
# 51132       SIDM01186 -0.700255
# 51133       SIDM00971 -0.039090
# 51134       SIDM00898 -0.819400
# 51142       SIDM00963  0.017132
# 51174       SIDM00922  0.486727
# 51178       SIDM00746 -0.646890
# 51183       SIDM00716 -0.866620
# 51194       SIDM00642  0.555317
# 51233       SIDM00489  0.208984
# 51238       SIDM00970 -0.632756
# 51240       SIDM00278  0.133638
# 51242       SIDM00591  0.539733
# 51296       SIDM00117  0.329769
# 51328       SIDM00513 -0.473141
# 51356       SIDM00860  0.411911
# 51421       SIDM01027  0.622966
# 51473       SIDM01147 -1.911683
# 51481       SIDM00743  0.636719
# 51503       SIDM00403  0.680025
# 51528       SIDM00814  0.597596
# 51535       SIDM00837 -0.169167
# 51560       SIDM00479 -1.172528
# 51609       SIDM00540 -0.234751
# ...

# %%
expression_data = pd.read_csv("CCLE_expression.csv")
expression_data.columns.values[0] = 'DepMap_ID'

# %%
merged_expression_sensitivity = pd.merge(expression_data, merged_data, how='inner', on = 'DepMap_ID')

# %%
merged_expression_sensitivity
# Out:
#       DepMap_ID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0    ACH-000242       7.465648      0.000000     6.435462       2.414136
# 1    ACH-000233       0.097611      0.000000     5.919102       3.983678
# 2    ACH-001655       4.376429      0.000000     6.679480       0.925999
# 3    ACH-000792       3.798051      0.000000     6.197708       1.739848
# 4    ACH-000351       4.614121      0.000000     8.070443       2.356144
# ..          ...            ...           ...          ...            ...
# 569  ACH-000114       3.793896      0.028569     6.330738       2.792855
# 570  ACH-001578       7.043848      3.354734     7.145066       2.482848
# 571  ACH-000973       5.026800      0.000000     6.966130       1.899176
# 572  ACH-000750       4.173127      0.000000     6.400879       1.807355
# 573  ACH-000052       4.870858      0.000000     6.077457       2.304511
#
#      C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  ...  \
# ...

# %%
merged_expression_sensitivity.columns
# Out:
# Index(['DepMap_ID', 'TSPAN6 (7105)', 'TNMD (64102)', 'DPM1 (8813)',
#        'SCYL3 (57147)', 'C1orf112 (55732)', 'FGR (2268)', 'CFH (3075)',
#        'FUCA2 (2519)', 'GCLC (2729)',
#        ...
#        'PUTATIVE_TARGET', 'PATHWAY_NAME', 'COMPANY_ID', 'WEBRELEASE',
#        'MIN_CONC', 'MAX_CONC', 'LN_IC50', 'AUC', 'RMSE', 'Z_SCORE'],
#       dtype='object', length=19218)

# %%
LN_IC50 = drug_sensitivity["LN_IC50"]

# %%
expression_data
# Out:
#        DepMap_ID  TSPAN6 (7105)  TNMD (64102)  DPM1 (8813)  SCYL3 (57147)  \
# 0     ACH-001113       4.990501      0.000000     7.273702       2.765535
# 1     ACH-001289       5.209843      0.545968     7.070604       2.538538
# 2     ACH-001339       3.779260      0.000000     7.346425       2.339137
# 3     ACH-001538       5.726831      0.000000     7.086189       2.543496
# 4     ACH-000242       7.465648      0.000000     6.435462       2.414136
# ...          ...            ...           ...          ...            ...
# 1388  ACH-000750       4.173127      0.000000     6.400879       1.807355
# 1389  ACH-000285       0.097611      0.000000     6.428276       3.257011
# 1390  ACH-001858       5.045268      0.000000     6.991749       1.807355
# 1391  ACH-001997       5.805292      0.000000     7.792855       2.482848
# 1392  ACH-000052       4.870858      0.000000     6.077457       2.304511
#
#       C1orf112 (55732)  FGR (2268)  CFH (3075)  FUCA2 (2519)  GCLC (2729)  \
# ...

# %%
drug_sensitivity.describe
# Out:
# <bound method NDFrame.describe of        DATASET  NLME_RESULT_ID  NLME_CURVE_ID  COSMIC_ID CELL_LINE_NAME  \
# 0        GDSC2             282       13320532     749709        HCC1954
# 1        GDSC2             282       13320565     749710        HCC1143
# 2        GDSC2             282       13320598     749711        HCC1187
# 3        GDSC2             282       13320631     749712        HCC1395
# 4        GDSC2             282       13320668     749713        HCC1599
# ...        ...             ...            ...        ...            ...
# 135237   GDSC2             282       13322622    1290798       EFM-192A
# 135238   GDSC2             282       13322655    1290905        HCC1428
# 135239   GDSC2             282       13322694    1290922         HDQ-P1
# 135240   GDSC2             282       13322727    1298157         JIMT-1
# 135241   GDSC2             282       13322759    1303900        HCC1500
#
#        SANGER_MODEL_ID TCGA_DESC  DRUG_ID     DRUG_NAME  \
# ...

# %%
# Number of genes
num_genes = expression_data.shape[1]
print(f"The number of genes is: {num_genes}")
# Out:
# The number of genes is: 19178

# %%
merged_expression_sensitivity.sex
# Out:
# 0        Male
# 1        Male
# 2      Female
# 3        Male
# 4        Male
#         ...
# 569    Female
# 570      Male
# 571      Male
# 572      Male
# 573    Female
# Name: sex, Length: 574, dtype: object

# %%
# Data Cleaning: handle missing or incorrect values
plot_df = merged_expression_sensitivity[['LN_IC50', 'sex', 'age', 'lineage']].dropna()
plot_df = plot_df[plot_df['sex'].isin(['Male', 'Female'])]

# 1. Gender Comparison
plt.figure(figsize=(8, 6))
if not plot_df.empty:
    sns.boxplot(x='sex', y='LN_IC50', data=plot_df)
    plt.title('Lapatinib Sensitivity by Gender')
    plt.savefig("Lapatinib Sensitivity by Gender.png")
    plt.show()
else:
    print("No data to plot for Gender Comparison.")

# 2. Age Group Analysis
plot_df['age_group'] = pd.cut(plot_df['age'], bins=[0, 30, 50, 70, 100], labels=['<30', '30-50', '51-70', '70+'])
plt.figure(figsize=(10, 6))
if not plot_df.empty:
    sns.violinplot(x='age_group', y='LN_IC50', data=plot_df)
    plt.title('Lapatinib Sensitivity by Age Group')
    plt.savefig("Lapatinib Sensitivity by Age Group.png")
    plt.show()
else:
    print("No data to plot for Age Group Analysis.")

# 3. Cancer Type
plt.figure(figsize=(12, 6))
if not plot_df.empty:
    cancer_order = plot_df.groupby('lineage')['LN_IC50'].median().sort_values().index
    sns.barplot(x='lineage', y='LN_IC50', data=plot_df, order=cancer_order)
    plt.xticks(rotation=90)
    plt.title('Lapatinib Sensitivity by Cancer Type')
    plt.tight_layout()
    plt.savefig("Lapatinib Sensitivity by Cancer Type.png")
    plt.show()
else:
    print("No data to plot for Cancer Type.")
# Out:
# C:\Users\dimim\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
plot_df
# Out:
#       LN_IC50     sex   age        lineage age_group
# 0    3.689474    Male  63.0  urinary_tract     51-70
# 1    1.756594    Male  12.0     lymphocyte       <30
# 2    4.181628  Female  52.0         uterus     51-70
# 3    1.391909    Male  64.0         kidney     51-70
# 4    2.315312    Male  72.0        gastric       70+
# ..        ...     ...   ...            ...       ...
# 568  3.622349    Male  62.0           skin     51-70
# 569  7.066646  Female  57.0       pancreas     51-70
# 571  3.747392    Male  69.0  urinary_tract     51-70
# 572  2.017927    Male  58.0           skin     51-70
# 573  3.659382  Female  15.0           bone       <30
#
# [472 rows x 5 columns]

# %%
# 1. Gender Distribution
plt.figure(figsize=(6, 4))
sns.countplot(x='sex', data=plot_df)
plt.title('Distribution of Samples by Gender')
plt.savefig("Gender_Distribution.png")
plt.show()

# 2. Age Group Distribution
plot_df['age_group'] = pd.cut(plot_df['age'], bins=[0, 30, 50, 70, 100], labels=['<30', '30-50', '51-70', '70+'])
plt.figure(figsize=(8, 5))
sns.countplot(x='age_group', data=plot_df, order=['<30', '30-50', '51-70', '70+'])
plt.title('Distribution of Samples by Age Group')
plt.savefig("Age_Group_Distribution.png")
plt.show()

# 3. Cancer Type Distribution
plt.figure(figsize=(12, 6))
sns.countplot(y='lineage', data=plot_df, order=plot_df['lineage'].value_counts().index)
plt.title('Distribution of Samples by Cancer Type')
plt.tight_layout()
plt.savefig("Cancer_Type_Distribution.png")
plt.show()
# Out:
# C:\Users\dimim\anaconda3\Lib\site-packages\seaborn\categorical.py:641: FutureWarning: The default of observed=False is deprecated and will be changed to True in a future version of pandas. Pass observed=False to retain current behavior or observed=True to adopt the future default and silence this warning.
#   grouped_vals = vals.groupby(grouper)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load your metadata file
metadata = pd.read_csv("sample_info.csv")  # Adjust filename if needed

# Check how the column for primary/metastasis is named
print(metadata.columns)

# Assuming the relevant column is named 'Primary_or_Metastatic'
primary_meta_counts = metadata['primary_or_metastasis'].value_counts()

# Create a bar plot
plt.figure(figsize=(6,4))
sns.barplot(x=primary_meta_counts.index, y=primary_meta_counts.values, palette="coolwarm")
plt.xlabel("Cancer Type")
plt.ylabel("Number of Cell Lines")
plt.title("Distribution of Primary vs. Metastatic Cancer Cell Lines")
plt.savefig("Primary vs. Metastatic - Lapatinib.png")
plt.show()
# Out:
# Index(['DepMap_ID', 'cell_line_name', 'stripped_cell_line_name', 'CCLE_Name',
#        'alias', 'COSMICID', 'sex', 'source', 'RRID', 'WTSI_Master_Cell_ID',
#        'sample_collection_site', 'primary_or_metastasis', 'primary_disease',
#        'Subtype', 'age', 'Sanger_Model_ID', 'depmap_public_comments',
#        'lineage', 'lineage_subtype', 'lineage_sub_subtype',
#        'lineage_molecular_subtype', 'culture_type'],
#       dtype='object')
